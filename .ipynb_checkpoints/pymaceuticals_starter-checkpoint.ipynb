# %% [markdown]
# # Pymaceuticals Inc.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
mouse_res = pd.merge(mouse_metadata, study_results, on="Mouse ID" )

# Display the data table for preview
mouse_res.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Checking the number of mice.
Unique_Mice = mouse_res['Mouse ID'].unique()
Total_Unique_Mice = len(mouse_res['Mouse ID'].unique())

print(f"Total Number of Unique Mice is: {Total_Unique_Mice}")
# Out:
# Total Number of Unique Mice is: 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 

mouse_res['Duplicated'] = mouse_res.duplicated(subset=['Mouse ID','Timepoint'])

dup_mice = mouse_res[mouse_res['Duplicated']==True] 
dup_mice[['Mouse ID','Timepoint']]
# Out:
#     Mouse ID  Timepoint
# 909     g989          0
# 911     g989          5
# 913     g989         10
# 915     g989         15
# 917     g989         20

# %%
# Optional: Get all the data for the duplicate mouse ID. 
dup_mice
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites  Duplicated
# 909           45.000000                 0        True
# 911           47.570392                 0        True
# 913           49.880528                 0        True
# 915           53.442020                 0        True
# 917           54.657650                 1        True

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
cleaned_data = mouse_res[mouse_res['Mouse ID'].isin(dup_mice)==False]

#reset / cleaned data
cleaned_data.reset_index(drop= True, inplace=True) 

cleaned_data.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites  Duplicated
# 0           45.000000                 0       False
# 1           38.825898                 0       False
# 2           35.014271                 1       False
# 3           34.223992                 1       False
# 4           32.997729                 1       False

# %%
# Checking the number of mice in the clean DataFrame.
cleaned_total = len(cleaned_data['Mouse ID'].unique())

print(f"Total Number of Cleaned Mice is: {cleaned_total}")
# Out:
# Total Number of Cleaned Mice is: 249

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# This method is the most straighforward, creating multiple series and putting them all together at the end.
Summary_Stats_df = cleaned_data.groupby('Drug Regimen').agg(Mean=('Tumor Volume (mm3)', 'mean'), Median=('Tumor Volume (mm3)', 'median'),
                                               Var=('Tumor Volume (mm3)', 'var'), Std_Dev=('Tumor Volume (mm3)', 'std'), 
                                               SEM=('Tumor Volume (mm3)', 'sem'))

Summary_Stats_df
# Out:
#                    Mean     Median        Var   Std_Dev       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.322552  50.854632  42.351070  6.507770  0.512884
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# This method produces everything in a single groupby function
Summary_Stats_df = cleaned_data.groupby('Drug Regimen').agg(Mean=('Tumor Volume (mm3)', 'mean'), Median=('Tumor Volume (mm3)', 'median'),
                                               Var=('Tumor Volume (mm3)', 'var'), Std_Dev=('Tumor Volume (mm3)', 'std'), 
                                               SEM=('Tumor Volume (mm3)', 'sem'))
Summary_Stats_df
# Out:
#                    Mean     Median        Var   Std_Dev       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.322552  50.854632  42.351070  6.507770  0.512884
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pandas. 

barplot = cleaned_data.groupby(["Drug Regimen"])["Mouse ID"].count()
barplot = barplot.sort_values(ascending=False)

barplot.plot(kind='bar', title='Total number of treatment', 
                     color='green',width=0.5, ylabel="Total Count",legend=False )
# Out:
# <AxesSubplot:title={'center':'Total number of treatment'}, xlabel='Drug Regimen', ylabel='Total Count'>

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pyplot.
x_axis = cleaned_data["Drug Regimen"].unique()
plt.bar(x_axis, barplot, color='blue', width=0.6, alpha=0.7)
plt.xlabel("Drug Regimen")
plt.ylabel("Total Count")
plt.xticks(rotation='vertical')
plt.title("Total number of treatment", fontsize=16)
plt.savefig("Treatment.png")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
pieplot = cleaned_data.groupby(['Sex'])['Mouse ID'].count()
pieplot.plot(kind='pie',colors=['orange','blue'], startangle=90, autopct = "%.2f%%", ylabel='', title='Gender (Using Pandas)')
plt.savefig("Gender.png")

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
pieplot2 = cleaned_data.groupby(['Sex'])['Mouse ID'].count()
labels = ['Female', 'Male']
colors = ['orange','blue']
plt.title('Gender (Using PyPlot)')

plt.pie(pieplot2, labels=labels, colors=colors,
        autopct="%.2f%%", shadow=False, startangle=90)
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

last_tum_vol = pd.DataFrame(cleaned_data.groupby('Mouse ID')['Timepoint'].max()).rename(columns={'Timepoint': 'Last Timepoint'})

# Start by getting the last (greatest) timepoint for each mouse
last_tum_vol.reset_index(inplace=True)


# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
merged_res = pd.merge(cleaned_data, last_tum_vol, on='Mouse ID')

merged_res
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites  Duplicated  Last Timepoint
# 0              45.000000                 0       False              45
# 1              38.825898                 0       False              45
# 2              35.014271                 1       False              45
# 3              34.223992                 1       False              45
# 4              32.997729                 1       False              45
# ...                  ...               ...         ...             ...
# 1888           63.145652                 2       False              45
# 1889           65.841013                 3       False              45
# 1890           69.176246                 4       False              45
# 1891           70.314904                 4       False              45
# 1892           73.867845                 4       False              45
#
# [1893 rows x 10 columns]

# %%
       
# Put treatments into a list for for loop (and later for plot labels)
drugs = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin','Stelasyn', 'Zoniferol', 'Ketapril', 'Propriva', 'Naftisol']
# Create empty list to fill with tumor vol data (for plotting)
treatment_list = []

i = 0

for drug in drugs:
    temp_res = merged_res.loc[merged_res['Drug Regimen'] == drug]
    final_res = temp_res.loc[temp_res['Timepoint'] == temp_res['Last Timepoint']]
    values = final_results['Tumor Volume (mm3)']
    treatment_list.append(values)
    quartiles = values.quantile([.25,.5,.75])
    
    # Upper, Lower, IQR, Median
    LowerQ = quartiles[0.25]
    print(f'The Lower Quartile for {drug} is {LowerQ}')
    
    UpperQ = quartiles[0.75]
    print(f'The Upper Quartile for {drug} is {UpperQ}')
     
    IQR = UpperQ-LowerQ
    print(f'The Inter Quartile Range for {drug} is: {IQR}')
    
    print(f'The Median result for {drug} is: {quartiles[0.5]}')
    
    #     Potential Outliers for each Drug
    out_lower = LowerQ - (1.5*iqr)
    out_upper = UpperQ + (1.5*iqr)
    print(f'The potential Outliers is {out_lower} for {drug}.')
    print(f'The potential Outliers is {out_upper} for {drug}.')
   
    print(f'xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')
    

outliers = merged_res.loc[(merged_res['Tumor Volume (mm3)'] < out_lower) | (merged_res['Tumor Volume (mm3)'] > out_upper)]
print(f'\n')
print(f'DataFrame of Potential Outliers Mice')
outliers
# Out:
# The Lower Quartile for Capomulin is 52.07951009
# The Upper Quartile for Capomulin is 69.56362076
# The Inter Quartile Range for Capomulin is: 17.484110670000007
# The Median result for Capomulin is: 63.28328821
# The potential Outliers is 25.85334408499999 for Capomulin.
# The potential Outliers is 95.78978676500002 for Capomulin.
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# The Lower Quartile for Ramicane is 52.07951009
# The Upper Quartile for Ramicane is 69.56362076
# The Inter Quartile Range for Ramicane is: 17.484110670000007
# The Median result for Ramicane is: 63.28328821
# The potential Outliers is 25.85334408499999 for Ramicane.
# The potential Outliers is 95.78978676500002 for Ramicane.
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# The Lower Quartile for Infubinol is 52.07951009
# The Upper Quartile for Infubinol is 69.56362076
# The Inter Quartile Range for Infubinol is: 17.484110670000007
# The Median result for Infubinol is: 63.28328821
# The potential Outliers is 25.85334408499999 for Infubinol.
# The potential Outliers is 95.78978676500002 for Infubinol.
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# The Lower Quartile for Ceftamin is 52.07951009
# The Upper Quartile for Ceftamin is 69.56362076
# The Inter Quartile Range for Ceftamin is: 17.484110670000007
# The Median result for Ceftamin is: 63.28328821
# The potential Outliers is 25.85334408499999 for Ceftamin.
# The potential Outliers is 95.78978676500002 for Ceftamin.
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# The Lower Quartile for Stelasyn is 52.07951009
# The Upper Quartile for Stelasyn is 69.56362076
# The Inter Quartile Range for Stelasyn is: 17.484110670000007
# The Median result for Stelasyn is: 63.28328821
# The potential Outliers is 25.85334408499999 for Stelasyn.
# The potential Outliers is 95.78978676500002 for Stelasyn.
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# The Lower Quartile for Zoniferol is 52.07951009
# The Upper Quartile for Zoniferol is 69.56362076
# The Inter Quartile Range for Zoniferol is: 17.484110670000007
# The Median result for Zoniferol is: 63.28328821
# The potential Outliers is 25.85334408499999 for Zoniferol.
# The potential Outliers is 95.78978676500002 for Zoniferol.
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# The Lower Quartile for Ketapril is 52.07951009
# The Upper Quartile for Ketapril is 69.56362076
# The Inter Quartile Range for Ketapril is: 17.484110670000007
# The Median result for Ketapril is: 63.28328821
# The potential Outliers is 25.85334408499999 for Ketapril.
# The potential Outliers is 95.78978676500002 for Ketapril.
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# The Lower Quartile for Propriva is 52.07951009
# The Upper Quartile for Propriva is 69.56362076
# The Inter Quartile Range for Propriva is: 17.484110670000007
# The Median result for Propriva is: 63.28328821
# The potential Outliers is 25.85334408499999 for Propriva.
# The potential Outliers is 95.78978676500002 for Propriva.
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# The Lower Quartile for Naftisol is 52.07951009
# The Upper Quartile for Naftisol is 69.56362076
# The Inter Quartile Range for Naftisol is: 17.484110670000007
# The Median result for Naftisol is: 63.28328821
# The potential Outliers is 25.85334408499999 for Naftisol.
# The potential Outliers is 95.78978676500002 for Naftisol.
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
#
# DataFrame of Potential Outliers Mice
#    Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 8      k403     Ramicane    Male          21          16         40
# 9      k403     Ramicane    Male          21          16         45
# 18     s185    Capomulin  Female           3          17         40
# 19     s185    Capomulin  Female           3          17         45
#
#     Tumor Volume (mm3)  Metastatic Sites  Duplicated  Last Timepoint
# 8            24.365505                 1       False              45
# 9            22.050126                 1       False              45
# 18           25.472143                 1       False              45
# 19           23.343598                 1       False              45

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

plt.boxplot(treatment_list)

# # Add title and labels to boxplot
# plt.title('Results for Tumor Volume (mm3) by Drugs')
# plt.ylabel('Tumor Volume (mm3)')
# # plt.xticks([1, 2, 3, 4], ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin','Stelasyn', 'Zoniferol', 'Ketapril', 'Propriva', 'Naftisol'])
# plt.savefig("mice_4drugs.png")
# plt.show()
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21cb3e53040>,
#   <matplotlib.lines.Line2D at 0x21cb3e53fd0>,
#   <matplotlib.lines.Line2D at 0x21cb3e443a0>,
#   <matplotlib.lines.Line2D at 0x21cb3b98ac0>,
#   <matplotlib.lines.Line2D at 0x21cb3e37e50>,
#   <matplotlib.lines.Line2D at 0x21cb3e376a0>,
#   <matplotlib.lines.Line2D at 0x21cb3e00190>,
#   <matplotlib.lines.Line2D at 0x21cb3e009d0>,
#   <matplotlib.lines.Line2D at 0x21cb3db4910>,
#   <matplotlib.lines.Line2D at 0x21cb3db4bb0>,
#   <matplotlib.lines.Line2D at 0x21cb3e057f0>,
#   <matplotlib.lines.Line2D at 0x21cb3e05460>,
#   <matplotlib.lines.Line2D at 0x21cb3dfadc0>,
#   <matplotlib.lines.Line2D at 0x21cb3dfaaf0>,
#   <matplotlib.lines.Line2D at 0x21cb3d12610>,
#   <matplotlib.lines.Line2D at 0x21cb3dc19a0>,
#   <matplotlib.lines.Line2D at 0x21cb3d9e9d0>,
#   <matplotlib.lines.Line2D at 0x21cb3d9e190>],
#  'caps': [<matplotlib.lines.Line2D at 0x21cb3e537c0>,
#   <matplotlib.lines.Line2D at 0x21cb2a72340>,
#   <matplotlib.lines.Line2D at 0x21cb3e20ca0>,
#   <matplotlib.lines.Line2D at 0x21cb3e205b0>,
#   <matplotlib.lines.Line2D at 0x21cb3e375b0>,
#   <matplotlib.lines.Line2D at 0x21cb3e379d0>,
#   <matplotlib.lines.Line2D at 0x21cb3e007f0>,
#   <matplotlib.lines.Line2D at 0x21cb3bcfc40>,
#   <matplotlib.lines.Line2D at 0x21cb3db4070>,
#   <matplotlib.lines.Line2D at 0x21cb3dee7f0>,
#   <matplotlib.lines.Line2D at 0x21cb3e05610>,
#   <matplotlib.lines.Line2D at 0x21cb3e05310>,
#   <matplotlib.lines.Line2D at 0x21cb3dcfc40>,
#   <matplotlib.lines.Line2D at 0x21cb3dcf100>,
#   <matplotlib.lines.Line2D at 0x21cb3dc1730>,
#   <matplotlib.lines.Line2D at 0x21cb3dc1ca0>,
#   <matplotlib.lines.Line2D at 0x21cb3d9ea60>,
#   <matplotlib.lines.Line2D at 0x21cb3d9e670>],
#  'boxes': [<matplotlib.lines.Line2D at 0x21cb3e98430>,
#   <matplotlib.lines.Line2D at 0x21cb3e44760>,
#   <matplotlib.lines.Line2D at 0x21cb3e372b0>,
#   <matplotlib.lines.Line2D at 0x21cb3e001c0>,
#   <matplotlib.lines.Line2D at 0x21cb3db4fd0>,
#   <matplotlib.lines.Line2D at 0x21cb3dee850>,
#   <matplotlib.lines.Line2D at 0x21cb3dfa790>,
#   <matplotlib.lines.Line2D at 0x21cb3dcf250>,
#   <matplotlib.lines.Line2D at 0x21cb3d20910>],
#  'medians': [<matplotlib.lines.Line2D at 0x21cb3e44bb0>,
#   <matplotlib.lines.Line2D at 0x21cb3e20d30>,
#   <matplotlib.lines.Line2D at 0x21cb3d330d0>,
#   <matplotlib.lines.Line2D at 0x21cb3cf9580>,
#   <matplotlib.lines.Line2D at 0x21cb3deea90>,
#   <matplotlib.lines.Line2D at 0x21cb3e05ac0>,
#   <matplotlib.lines.Line2D at 0x21cb3dcf730>,
#   <matplotlib.lines.Line2D at 0x21cb3dc1040>,
#   <matplotlib.lines.Line2D at 0x21cb3de6100>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21cb3e44ca0>,
#   <matplotlib.lines.Line2D at 0x21cb3e20a30>,
#   <matplotlib.lines.Line2D at 0x21cb3d33340>,
#   <matplotlib.lines.Line2D at 0x21cb3db4430>,
#   <matplotlib.lines.Line2D at 0x21cb3dee790>,
#   <matplotlib.lines.Line2D at 0x21cb3dfa340>,
#   <matplotlib.lines.Line2D at 0x21cb3dcfcd0>,
#   <matplotlib.lines.Line2D at 0x21cb3dc10a0>,
#   <matplotlib.lines.Line2D at 0x21cb3de61f0>],
#  'means': []}

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
